# %%
cd ..
# Out:
# /home/max/Documents/wapiesz

# %%
import pandas as pd
import os
import memenet

# %%
memenet.memes
# Out:
#                                                   caption        file  \
# 0        my mom when i play with my phone for 30 minut...  3xd5o0.jpg
# 1        Doing your own research for a test Copy and p...  3xctnx.jpg
# 2        1,000,000 followers on tik tok 1 point on img...  3wu3bd.jpg
# 3        Making original memes Following the idea of a...  3xb1dj.jpg
# 4                                                      M   3w8qn4.jpg
# ...                                                   ...         ...
# 202203                              CHECK THE SYLLABUS!!   22vtzg.jpg
# 202204                           THIS .....IS ....INFJ!!   20uumk.jpg
# 202205          TTW MUM FORGOT TO PACK CRISPS WITH LUNCH   2lrvrg.jpg
# 202206                                          OI KURWA   2byavg.jpg
# 202207             A YOU YES I WILL FIGHT FOR MY BROTHES   2095sc.jpg
#
#                    template template_file    set
# 0       Drake Hotline Bling    30b1gx.jpg  train
# ...

# %%
memenet.dataset.load_image('3xd5o0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F3404D58D30>
