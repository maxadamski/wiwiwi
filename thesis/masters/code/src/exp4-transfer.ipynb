# %%
cd ..
# Out:
# /home/max/Documents/mgr

# %%
import numpy as np
import pandas as pd
import torch as T
import torch.nn.functional as F
import torch.nn as nn
from sklearn import metrics
from sklearn.decomposition import PCA
from tqdm import tqdm

from src.simplefact import *
from src.simplefact import Reasoner as FACT
from src.ontofun import *
from src.syntax import *
from src.reasoneur import *
from src.generate import *
from src.utils import *
from src.vis import *

seed = 2022

# %%
onto = load_owl('local/manchester-pizza.owl')
onto.use_annotations_as_names()
onto.use_prefix('pizza:')
fact = FACT(n_concepts=onto.n_concepts, n_roles=onto.n_roles, timeout=10_000)
for axiom in onto.tbox:
    fact.add_axiom(axiom)
    
C = onto.concept_by_name
R = onto.role_by_name
onto
# Out:
# Unsupported class expression ('SubClassOf', 'pizza:American', ('ObjectHasValue', 'pizza:hasCountryOfOrigin', 'pizza:America'))
# Unsupported class expression ('SubClassOf', 'pizza:AmericanHot', ('ObjectHasValue', 'pizza:hasCountryOfOrigin', 'pizza:America'))
# Unsupported class expression ('EquivalentClasses', 'pizza:Country', ('ObjectIntersectionOf', 'pizza:DomainConcept', ('ObjectOneOf', 'pizza:America', 'pizza:England', 'pizza:France', 'pizza:Germany', 'pizza:Italy')))
# Unsupported class expression ('EquivalentClasses', 'pizza:InterestingPizza', ('ObjectIntersectionOf', 'pizza:Pizza', ('ObjectMinCardinality', '3', 'pizza:hasTopping')))
# Unsupported class expression ('SubClassOf', 'pizza:MozzarellaTopping', ('ObjectHasValue', 'pizza:hasCountryOfOrigin', 'pizza:Italy'))
# Unsupported class expression ('SubClassOf', 'pizza:Napoletana', ('ObjectHasValue', 'pizza:hasCountryOfOrigin', 'pizza:Italy'))
# Unsupported class expression ('EquivalentClasses', 'pizza:RealItalianPizza', ('ObjectIntersectionOf', 'pizza:Pizza', ('ObjectHasValue', 'pizza:hasCountryOfOrigin', 'pizza:Italy')))
# Unsupported class expression ('SubClassOf', 'pizza:Veneziana', ('ObjectHasValue', 'pizza:hasCountryOfOrigin', 'pizza:Italy'))
# Dropping unused role pizza:hasCountryOfOrigin
# Dropping unused role pizza:hasIngredient
# Dropping unused role pizza:isBaseOf
# Dropping unused role pizza:isIngredientOf
# Dropping unused role pizza:isToppingOf
# <Onto 99 concepts, 3 roles, 280 axioms>

# %%
rng = np.random.default_rng(seed)
Nc = onto.n_concepts
Nr = onto.n_roles
gen = AxiomGenerator(rng=rng, n_concepts=Nc, n_roles=Nr, max_depth=4)
        
n_queries = 30_000
queries, answers, qset = [], [], set()
while len(queries) < n_queries:
    #print(f'\r{len(queries)}/{n_queries}', end='')
    axiom = gen()
    if axiom in queries: continue
    
    answer = fact.check_axiom(axiom)
    queries.append(axiom); answers.append(float(answer)); qset.add(axiom)
    
print(to_pretty(queries[100], onto=onto))
print(len(answers))
print(np.round(np.mean(answers), 4))
# Out:
# VegetarianPizza ⊔ CheesyVegetableTopping != OliveTopping
# 30000
# 0.3704

# %%
Reasoner = ContextFreeReasoner
Encoder = NNExprEncoder
Optimizer = T.optim.AdamW
expr_size = 10

hidden_size = 16
epoch_count = 30 + 1
batch_size = 32
lr_reasoner = 0.002
lr_encoder = lr_reasoner

X_te = [core(x) for x in queries]
y_te = answers
idx_te = [0]*len(X_te)

test_history = []
test_history_by_onto = []
rng = np.random.default_rng(seed)
T.manual_seed(seed)
reasoner = Reasoner(expr_size=expr_size, hidden_size=hidden_size)
reasoner.load_state_dict(T.load('local/out/exp/20220622T073936/reasoner.pt'))
freeze(reasoner)
reasoner_optim = Optimizer(reasoner.parameters(), lr=lr_reasoner)
encoder = Encoder.from_onto(onto, expr_size=expr_size)
encoder_optim = Optimizer(encoder.parameters(), lr=lr_encoder)
print(paramcount(reasoner))
print(paramcount(encoder))

test(test_data=(idx_te, X_te, y_te), test_onto=[onto],
     reasoner=reasoner, reasoner_name='pizza_reasoner',
     encoders=[encoder], optimizers=[encoder_optim],
     test_hist=test_history, test_hist_by_onto=test_history_by_onto,
     epoch_count=epoch_count, batch_size=batch_size)
# Out:
# 3283
# 1330
# test epoch 01/31 | batch 938/938 | test loss 1.0850 | acc 0.6202 | f1 0.5667 | prec 0.4907 | recall 0.6706 | roc auc 0.6900 | elapsed 8.57s
# test epoch 02/31 | batch 938/938 | test loss 0.2537 | acc 0.9083 | f1 0.8725 | prec 0.8993 | recall 0.8472 | roc auc 0.9552 | elapsed 12.69s
# test epoch 03/31 | batch 938/938 | test loss 0.2230 | acc 0.9196 | f1 0.8895 | prec 0.9059 | recall 0.8737 | roc auc 0.9653 | elapsed 12.77s
# test epoch 04/31 | batch 938/938 | test loss 0.2053 | acc 0.9283 | f1 0.9008 | prec 0.9230 | recall 0.8797 | roc auc 0.9697 | elapsed 12.62s
# test epoch 05/31 | batch 938/938 | test loss 0.1823 | acc 0.9406 | f1 0.9190 | prec 0.9292 | recall 0.9090 | roc auc 0.9745 | elapsed 12.63s
# test epoch 06/31 | batch 938/938 | test loss 0.1704 | acc 0.9451 | f1 0.9247 | prec 0.9399 | recall 0.9101 | roc auc 0.9772 | elapsed 12.64s
# test epoch 07/31 | batch 938/938 | test loss 0.1642 | acc 0.9483 | f1 0.9294 | prec 0.9409 | recall 0.9182 | roc auc 0.9786 | elapsed 12.83s
# test epoch 08/31 | batch 938/938 | test loss 0.1577 | acc 0.9504 | f1 0.9321 | prec 0.9448 | recall 0.9198 | roc auc 0.9801 | elapsed 12.56s
# test epoch 09/31 | batch 938/938 | test loss 0.1572 | acc 0.9505 | f1 0.9324 | prec 0.9436 | recall 0.9214 | roc auc 0.9806 | elapsed 12.61s
# test epoch 10/31 | batch 938/938 | test loss 0.1539 | acc 0.9511 | f1 0.9330 | prec 0.9467 | recall 0.9196 | roc auc 0.9814 | elapsed 12.51s
# test epoch 11/31 | batch 938/938 | test loss 0.1494 | acc 0.9542 | f1 0.9375 | prec 0.9485 | recall 0.9267 | roc auc 0.9820 | elapsed 12.58s
# test epoch 12/31 | batch 938/938 | test loss 0.1484 | acc 0.9529 | f1 0.9358 | prec 0.9445 | recall 0.9273 | roc auc 0.9824 | elapsed 12.54s
# test epoch 13/31 | batch 938/938 | test loss 0.1463 | acc 0.9537 | f1 0.9366 | prec 0.9493 | recall 0.9242 | roc auc 0.9830 | elapsed 12.77s
# test epoch 14/31 | batch 938/938 | test loss 0.1445 | acc 0.9552 | f1 0.9391 | prec 0.9467 | recall 0.9316 | roc auc 0.9832 | elapsed 12.60s
# test epoch 15/31 | batch 938/938 | test loss 0.1429 | acc 0.9552 | f1 0.9391 | prec 0.9464 | recall 0.9318 | roc auc 0.9836 | elapsed 12.58s
# test epoch 16/31 | batch 938/938 | test loss 0.1416 | acc 0.9559 | f1 0.9400 | prec 0.9485 | recall 0.9316 | roc auc 0.9838 | elapsed 12.63s
# test epoch 17/31 | batch 938/938 | test loss 0.1392 | acc 0.9568 | f1 0.9412 | prec 0.9490 | recall 0.9335 | roc auc 0.9843 | elapsed 12.67s
# test epoch 18/31 | batch 938/938 | test loss 0.1394 | acc 0.9560 | f1 0.9400 | prec 0.9482 | recall 0.9321 | roc auc 0.9845 | elapsed 12.77s
# test epoch 19/31 | batch 938/938 | test loss 0.1378 | acc 0.9575 | f1 0.9421 | prec 0.9519 | recall 0.9325 | roc auc 0.9848 | elapsed 12.85s
# test epoch 20/31 | batch 938/938 | test loss 0.1379 | acc 0.9559 | f1 0.9401 | prec 0.9453 | recall 0.9349 | roc auc 0.9850 | elapsed 13.06s
# test epoch 21/31 | batch 938/938 | test loss 0.1345 | acc 0.9582 | f1 0.9432 | prec 0.9509 | recall 0.9356 | roc auc 0.9853 | elapsed 12.81s
# test epoch 22/31 | batch 938/938 | test loss 0.1360 | acc 0.9572 | f1 0.9420 | prec 0.9471 | recall 0.9369 | roc auc 0.9852 | elapsed 12.87s
# test epoch 23/31 | batch 938/938 | test loss 0.1343 | acc 0.9587 | f1 0.9438 | prec 0.9515 | recall 0.9363 | roc auc 0.9856 | elapsed 12.76s
# test epoch 24/31 | batch 938/938 | test loss 0.1333 | acc 0.9589 | f1 0.9441 | prec 0.9515 | recall 0.9367 | roc auc 0.9857 | elapsed 12.88s
# test epoch 25/31 | batch 938/938 | test loss 0.1336 | acc 0.9593 | f1 0.9446 | prec 0.9541 | recall 0.9352 | roc auc 0.9857 | elapsed 12.80s
# test epoch 26/31 | batch 938/938 | test loss 0.1298 | acc 0.9598 | f1 0.9454 | prec 0.9511 | recall 0.9398 | roc auc 0.9862 | elapsed 12.71s
# test epoch 27/31 | batch 938/938 | test loss 0.1314 | acc 0.9601 | f1 0.9459 | prec 0.9502 | recall 0.9418 | roc auc 0.9859 | elapsed 13.26s
# test epoch 28/31 | batch 938/938 | test loss 0.1326 | acc 0.9583 | f1 0.9433 | prec 0.9489 | recall 0.9378 | roc auc 0.9860 | elapsed 12.94s
# test epoch 29/31 | batch 938/938 | test loss 0.1310 | acc 0.9585 | f1 0.9438 | prec 0.9472 | recall 0.9404 | roc auc 0.9862 | elapsed 12.66s
# test epoch 30/31 | batch 938/938 | test loss 0.1301 | acc 0.9595 | f1 0.9450 | prec 0.9512 | recall 0.9389 | roc auc 0.9864 | elapsed 12.70s
# test epoch 31/31 | batch 938/938 | test loss 0.1271 | acc 0.9612 | f1 0.9472 | prec 0.9566 | recall 0.9379 | roc auc 0.9868 | elapsed 12.77s

# %%
with T.no_grad():
    reasoner.eval()
    _, _, Y_te = eval_batch(reasoner, [encoder], X_te, y_te, idx_te)

# %%
test_history_by_onto = pd.DataFrame(test_history_by_onto)
test_history = pd.DataFrame(test_history)
test_results = pd.DataFrame(dict(idx_te=idx_te, y_te=y_te, Y_te_good=Y_te))
report([onto], y_te, Y_te, idx_te)
# Out:
#              mean  std     micro
# acc      0.961233  NaN  0.961233
# prec     0.956586  NaN  0.956586
# recall   0.937905  NaN  0.937905
# f1       0.947153  NaN  0.947153
# auc_roc  0.986849  NaN  0.986849
# ap       0.982760  NaN  0.982760

# %%
pizzann = ReasonerPackage(reasoner, encoder)

# %%
from umap import UMAP
pca = UMAP(n_components=2, n_neighbors=50, min_dist=0.6, random_state=seed)

exclude = {}
manual_exprs = [C[x] for x in C if x not in exclude]
manual_exprs += [TOP, BOT]

exprs, texts, colors, markers = [], [], [], []
for expr in manual_exprs:
    exprs.append(pizzann.encode(expr))
    texts.append(to_pretty(expr, onto=onto))
    
    if fact.check_eqv(expr, BOT):
        m = 's'
    elif fact.check_sub(expr, C.Pizza):
        m = 'o'
    elif fact.check_sub(expr, C.PizzaTopping):
        m = 'd'
    else:
        m = 's'
    
    c = 'gray'
    if isinstance(expr, tuple) or expr in {TOP, BOT}:
        c = 'cyan'
        m = 's'
    elif not fact.check_sub(expr, BOT):
        if fact.check_sub(expr, C.VegetarianPizza): c = 'lime'
        if fact.check_sub(expr, C.NonVegetarianPizza): c = 'brown'

        if fact.check_sub(expr, C.VegetarianTopping): c = 'lime'
        if fact.check_sub(expr, C.VegetableTopping): c = 'green'
        if fact.check_sub(expr, C.MeatTopping): c = 'brown'
        if fact.check_sub(expr, C.SeafoodTopping): c = 'pink'
        if fact.check_sub(expr, C.Spiciness): c = 'red'
    
    colors.append(c)
    markers.append(m)

xs, ys = pca.fit_transform(np.array(exprs)).T
for x, y, text, color, marker, expr in zip(xs, ys, texts, colors, markers, manual_exprs):
    plt.scatter(x, y, marker=marker, color=color)
    if not (isinstance(expr, tuple) or fact.check_sub(expr, BOT)):
        if fact.check_sub(expr, (OR, C.CheeseTopping, C.CheesyPizza)):
            plt.scatter(x, y, marker=marker, color='yellow', s=30)
        if fact.check_sub(expr, C.PepperTopping):
            plt.scatter(x, y, marker=marker, color='orange', s=30)
        if fact.check_sub(expr, (OR, C.SpicyTopping, C.SpicyPizza)):
            plt.scatter(x, y, marker='x', color='red', s=50)
    plt.text(x, y, text.replace('Topping', 'T'), fontsize=10)
    
#plt.xlim(7.3, 11.7)
plt.xticks([]); plt.yticks([])
plt.show()

# %%
df = []
for x, y, Y_proba in zip(X_te, y_te, Y_te):
    y, Y = bool(y), bool(Y_proba > 0.5)
    ok = y == Y 
    df.append(dict(
        y=y, Y=Y, correct=y == Y, proba=round(Y_proba, 6),
        depth=expr_depth(x),
        lbot=fact.check_eqv(x[1], BOT),
        rtop=fact.check_eqv(x[2], TOP),
        disj=x[0] == DIS,
        trivialeq=x[1] == x[2],
        axiom=to_pretty(x, onto=onto),
    ))
            
df = pd.DataFrame(df)
print(df.correct.mean())
df
# Out:
# 0.9612333333333334
#            y      Y  correct     proba  depth   lbot   rtop   disj  trivialeq  \
# 0      False  False     True  0.010212      1  False  False  False      False
# 1      False  False     True  0.005962      5  False  False  False      False
# 2      False  False     True  0.321336      1  False  False  False      False
# 3       True   True     True  0.998016      2   True  False  False      False
# 4       True  False    False  0.029220      3   True  False  False      False
# ...      ...    ...      ...       ...    ...    ...    ...    ...        ...
# 29995  False  False     True  0.014289      3  False  False  False      False
# 29996  False  False     True  0.345377      2  False  False  False      False
# 29997  False  False     True  0.000019      5  False  False  False      False
# 29998  False  False     True  0.000042      6  False  False  False      False
# 29999   True   True     True  0.999996      6   True  False  False      False
#
#                                                    axiom
# 0                    ValuePartition ⊑ SweetPepperTopping
# 1      SweetPepperTopping ⊓ ¬(∃hasBase.¬PineKernelTop...
# 2                                 Hot ⊑ VegetableTopping
# 3                      Veneziana ⊓ CajunSpiceTopping ⊑ ⊥
# 4                         ¬Capricciosa ⊓ Capricciosa ⊑ ⊥
# ...                                                  ...
# 29995      PeperoniSausageTopping ⊓ ¬QuattroFormaggi ⊑ ⊥
# 29996                  CheesyPizza ⊓ QuattroFormaggi ⊑ ⊥
# 29997  ∃hasBase.¬(¬PeperoniSausageTopping ⊓ ¬SpicyPiz...
# 29998  ¬(⊤ ⊓ ¬LeekTopping ⊓ ¬LeekTopping) ⊓ RealItali...
# 29999  ¬(¬Rosa ⊓ ¬OliveTopping) ⊓ PolloAdAstra ⊓ HotG...
#
# [30000 rows x 10 columns]

# %%
df.groupby('correct').mean()
# Out:
#                 y         Y     proba     depth      lbot      rtop  disj  \
# correct
# False    0.593293  0.406707  0.410742  3.140155  0.270851  0.011178   0.0
# True     0.361411  0.361411  0.364418  2.543503  0.343621  0.009675   0.0
#
#          trivialeq
# correct
# False     0.060189
# True      0.000173

# %%
print('correct', sum(df.correct))
print('incorrect', sum(~df.correct))
# Out:
# correct 28837
# incorrect 1163

# %%
xs = sorted(list(range(onto.n_concepts)), key=lambda i: onto.concepts[i])
ticks = [to_pretty(x, onto=onto).replace('Topping', 'T') for x in xs]
n = len(xs)
sub_fact = np.zeros((n, n))
sub_nn = np.zeros((n, n))
for i, c in enumerate(xs):
    for j, d in enumerate(xs):
        sub_fact[i][j] = fact.check_sub(c, d)
        sub_nn[i][j] = pizzann.check_sub(c, d)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30, 15))
sns.heatmap(sub_fact, xticklabels=ticks, yticklabels=ticks, cbar=False, cmap='cividis', ax=ax1)
sns.heatmap(sub_nn, xticklabels=ticks, yticklabels=ticks, cbar=False, cmap='cividis', ax=ax2)

#ax1.tick_params(axis='both', labelsize=8.9)
#ax2.tick_params(axis='both', labelsize=8.9)
for ax in [ax1, ax2]:
    ax.set_xticks([])
    ax.set_yticks([])
plt.grid(True)
plt.show()

# %%
test_history.groupby('test_epoch').max().elapsed.sum()
# Out:
# 290.148628950119
